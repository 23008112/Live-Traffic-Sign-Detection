# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#   Using cached numpy-2.3.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached pillow-11.3.0-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached scipy-1.16.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached torch-2.7.1-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached pandas-2.3.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\admin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\admin\\Downloads\\India Traffic Sign.v7i.yolov8888888'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="data.yaml" epochs=60 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.170  Python-3.12.6 torch-2.7.1+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# ...
